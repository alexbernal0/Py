# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#stats
from scipy import stats

# %%
#plot
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  2.,   1.,   8.,  18.,  19.,  22.,  16.,  11.,   1.,   2.]),
#  array([-2.83404227, -2.28251704, -1.7309918 , -1.17946656, -0.62794133,
#         -0.07641609,  0.47510914,  1.02663438,  1.57815962,  2.12968485,
#          2.68121009]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

plt.hist(dataset2,color='indianred')
# Out:
# (array([  3.,   1.,   2.,  10.,  17.,  21.,  10.,  10.,   3.,   3.]),
#  array([-2.94650322, -2.39682136, -1.84713949, -1.29745763, -0.74777576,
#         -0.1980939 ,  0.35158797,  0.90126983,  1.45095169,  2.00063356,
#          2.55031542]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20)
# Out:
# (array([ 0.13644256,  0.        ,  0.        ,  0.04548085,  0.        ,
#          0.09096171,  0.27288512,  0.18192341,  0.45480853,  0.31836597,
#          0.45480853,  0.50028938,  0.        ,  0.45480853,  0.04548085,
#          0.40932768,  0.13644256,  0.        ,  0.09096171,  0.04548085]),
#  array([-2.94650322, -2.67166229, -2.39682136, -2.12198042, -1.84713949,
#         -1.57229856, -1.29745763, -1.0226167 , -0.74777576, -0.47293483,
#         -0.1980939 ,  0.07674703,  0.35158797,  0.6264289 ,  0.90126983,
#          1.17611076,  1.45095169,  1.72579263,  2.00063356,  2.27547449,
#          2.55031542]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
#jointplots
sns.jointplot(data1,data2)

# %%
#hexplot
sns.jointplot(data1,data2,kind='hex')

# %%
#kernaldensity estimation plots

#carpetplot
dataset = randn(25)

# %%
sns.rugplot(dataset)

plt.ylim(0,1)
# Out:
# (0, 1)

# %%
plt.hist(dataset,alpha=0.3)
sns.rugplot(dataset)

# %%
sns.rugplot(dataset)

x_min = dataset.min() - 2
x_max = dataset.max() + 2

x_axis = np.linspace(x_min,x_max,100)

bandwidth = (  (4*dataset.std()**5) / (3*len(dataset))) ** 0.2

kernel_list = []

for data_point in dataset:
    
    #create a kernal for each point and append to kernal list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * 0.4
    
    plt.plot(x_axis,kernel,color='black',alpha=0.5)
    
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
sum_of_kde = np.sum(kernel_list,axis=0)

fig = plt.plot(x_axis,sum_of_kde,color='blue')

sns.rugplot(dataset)

#plt.ytick([])

plt.suptitle("Sum of the basis functions")

# %%
sns.rugplot(dataset,color='black')

for bw in np.arange(0.5,2,0.25):
    sns.kdeplot(dataset,bw=bw,lw=1.8,label=bw)

# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as wb

# %%
tickers = ['PG', 'MSFT', 'T', 'F', 'GE']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
new_data.tail()
# Out:
#                    PG       MSFT          T      F         GE
# Date
# 2017-04-17  89.703115  65.480003  40.299999  11.13  29.639999
# 2017-04-18  90.110003  65.389999  40.250000  11.14  29.840000
# 2017-04-19  89.599998  65.040001  40.250000  11.19  30.000000
# 2017-04-20  89.330002  65.500000  40.360001  11.47  30.270000
# 2017-04-21  88.620003  66.400002  39.930000  11.34  29.549999

# %%
sns.pairplot(new_data)

# %%
sns.distplot(new_data['MSFT'])

# %%
sns.heatmap(new_data.corr())

# %%
sns.heatmap(new_data.corr(),annot=True)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
#this will show the pplto in the jup notebook

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r-')

# %%
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
## fig methods -  created figure object
fig = plt.figure()

#call figure a method
axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('Larger')
axes2.plot(y,x)
axes2.set_title('Smaller')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig = plt.figure(figsize=(3,2),dpi=1000)

ax =  fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(figsize=(3,2),dpi=1000)

ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)

axes[1].plot(y,x)

# %%
#save a figure
fig.savefig('my_picture.png',dpi=200)

# %%
fig =plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')

# %%
#adding alegend

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label= 'X Cubed')

ax.legend(loc=0)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=0.5,ls='-',marker='o',markersize=2)

# %%
#distribution plots seaborn
import seaborn as sns

# %%
# %matplotlib inline 
#see visualizations within the notebook

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#distplot distribution 1 variable
sns.distplot(tips['total_bill'],bins=30)

# %%
#combine 2 dist plots
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
#combine 2 dist plots
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
#combine 2 dist plots
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
#combine 2 dist plots
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
#combine 2 dist plots
sns.pairplot(tips)

# %%
#combine 2 dist plots
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
#rugplots - explain KDEs
sns.rugplot(tips['total_bill'])

# %%
#kernal density estimation plots
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#create dataset
dataset = np.random.randn(25)

sns.rugplot(dataset);

x_min = dataset.min() - 2
x_max = dataset.max() + 2

x_axis = np.linspace(x_min,x_max,100)

url = 'http://en.wikipedia.org/wiki/kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

kernel_list = []

for data_point in dataset:
    
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)
    
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
#summ all normal dist to get KERNAl

sum_of_kde = np.sum(kernel_list,axis=0)

fig = plt.plot(x_axis,sum_of_kde,color='indianred')

sns.rugplot(dataset,c = 'indianred')

plt.yticks([])

plt.suptitle("sum of the basis functions")

# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
import numpy as np
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
#violin plots
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',split=True)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
#factorplot
sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')

# %%
##matrix Plots
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tc = tips.corr()

# %%
sns.heatmap(tc)

# %%
sns.heatmap(tc, annot=True)

# %%
sns.heatmap(tc, annot=True,cmap='coolwarm')

# %%
#convert list into a matrix
fp = flights.pivot_table(index='month', columns='year',values='passengers')

# %%
sns.heatmap(fp)

# %%
sns.heatmap(fp,cmap='magma',linecolor='white',linewidths=1)

# %%
sns.clustermap(fp)
# Out:
# C:\Users\alexb\AppData\Local\Enthought\Canopy\User\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
##LM Plots
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#specify 'hue' to sepearte by category
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':20})

# %%
#seperate by column
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %%
#size aspect
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',aspect=0.6,size=8)

# %%
#style color
sns.set_style('white')
sns.countplot(x='sex',data=tips)

# %%
#style color
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)

# %%
#style color
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips)

# %%
#style color
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips)
sns.despine()

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
sns.set_context('poster')
sns.countplot(x='sex',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='plasma',aspect=1,size=8)

# %%
#
